# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/kalyan369/Python_Practice/blob/master/AF_Matplotlib_Examples.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(facecolor=(1,0,0,.1))

# %%
plt.show()

# %%
fig = plt.figure(figsize=plt.figaspect(2.0),facecolor=(1,0,0,.1))

# %%
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set(xlim=[0.5,0.45], ylim=[-2,8], title='An Example Axes', ylabel='Y-Axis', xlabel='X-Axis')
plt.show()

# %%
# Above piece of code can also be written as below
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlim([0.5,.45])
ax.set_ylim([-2,8])
ax.set_title('A Different Example Axes Title')
ax.set_ylabel('Y-Axis (changed)')
ax.set_xlabel('X-Axis (changed)')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1,2,3,4],[10,20,25,30],color='lightblue',linewidth=3)
ax.scatter([0.6,3.8,1.2,2.5],[11,25,9,26],c=[1,2,3,5],marker='^')
ax.set_xlim(0.5,4.5)
# Out:
# (0.5, 4.5)

# %%
plt.plot([1,2,3,4],[10,20,25,30],color='lightblue',linewidth=3)
plt.scatter([0.6,3.8,1.2,2.5],[11,25,9,26],c=[1,2,3,5],marker='^')
plt.xlim(0.5,4.5)
plt.show()

# %%
fig, axes = plt.subplots(nrows=2,ncols=2) #It create 4 subplots
plt.show()

# %%
fig, axes = plt.subplots(nrows=2,ncols=2)
axes[0,0].set(title='Upper Left')
axes[0,1].set(title='Upper Right')
axes[1,0].set(title='Lower Left')
axes[1,1].set(title='Lower Right')

# To iterate over all items in a multidimensional numpy array use flat attribute

for ax in axes.flat:
  #Remove all xticks and yticks..
  ax.set(xticks=[],yticks=[])
  
plt.show()

# %%
#Really nicething about plt.subplots with no arguments is shown below
fig,ax = plt.subplots() # which is very similar what we created by assigning fig and ax seperately

# %%
x=np.linspace(0,10,100)
y1,y2,y3 = np.cos(x),np.cos(x+1),np.cos(x+2)
names = ['signal 1','signal 2','signal 3']
fig,axes = plt.subplots(nrows=3,ncols=1)
axes[0].set(title=names[0],xlim=[0,10],ylim=[-1.5,1.5])
axes[0].plot(x,y1,color='red',linewidth=3)
axes[1].set(title=names[1],xlim=[0,10],ylim=[-1.5,1.5])
axes[1].plot(x,y2,color='green',linewidth=3)
axes[2].set(title=names[2],xlim=[0,10],ylim=[-1.5,1.5])
axes[2].plot(x,y3,color='blue',linewidth=3)
